# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('multiple_linear_regression_dataset.csv')

# %%
df
# Out:
#     age  experience  income
# 0    25           1   30450
# 1    30           3   35670
# 2    47           2   31580
# 3    32           5   40130
# 4    43          10   47830
# 5    51           7   41630
# 6    28           5   41340
# 7    33           4   37650
# 8    37           5   40250
# 9    39           8   45150
# 10   29           1   27840
# 11   47           9   46110
# 12   54           5   36720
# 13   51           4   34800
# 14   44          12   51300
# 15   41           6   38900
# 16   58          17   63600
# 17   23           1   30870
# 18   44           9   44190
# 19   37          10   48700

# %%
df.isnull().sum()
# Out:
# age           0
# experience    0
# income        0
# dtype: int64

# %%
X = df.drop('income', axis=1)
y = df['income']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
y_pred
# Out:
# array([33535.88309102, 33442.33680007, 40955.90438168, 36438.40920362])

# %%
model.score(X_test,y_test)*100
# Out:
# 87.31813302143885

# %%
sns.relplot(df['age'],kind='line')

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
linear = LinearRegression()
linear.fit(X_train,y_train)
y_pred = linear.predict(X_test)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)*100
print('MAE: ',mae)
print('Score: ',score)
plt.scatter(y_test,y_pred)
# Out:
# MAE:  1793.9452386081393
# Score:  97.02130542111044

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error, r2_score
lasso = Lasso()
lasso.fit(X_train,y_train)
y_pred = lasso.predict(X_test)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)*100
print('MAE: ',mae)
print('Score: ',score)
plt.scatter(y_test,y_pred)
# Out:
# MAE:  1795.527828644059
# Score:  97.01785878229717

# %%
from sklearn.linear_model import LassoCV
from sklearn.metrics import mean_absolute_error, r2_score
lassocv = LassoCV(cv=5)
lassocv.fit(X_train,y_train)
y_pred = lassocv.predict(X_test)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)*100
print('MAE: ',mae)
print('Score: ',score)
plt.scatter(y_test,y_pred)
# Out:
# MAE:  1803.7280937142314
# Score:  96.99948126235356

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, r2_score
ridge = Ridge()
ridge.fit(X_train,y_train)
y_pred = ridge.predict(X_test)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)*100
print('MAE: ',mae)
print('Score: ',score)
plt.scatter(y_test,y_pred)
# Out:
# MAE:  2391.3078593901437
# Score:  95.24901495850469

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error, r2_score
elastic = ElasticNet()
elastic.fit(X_train,y_train)
y_pred = elastic.predict(X_test)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)*100
print('MAE: ',mae)
print('Score: ',score)
plt.scatter(y_test,y_pred)
# Out:
# MAE:  5384.297915267887
# Score:  80.49142307688652

# %%
scaler
# Out:
# StandardScaler()

# %%
mod
# Out:
# LassoCV(cv=5)

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(lassocv,open('lassocv.pkl','wb'))
